# %%
import pandas as pd

archivos = [
    "/content/sample_data/viirs-snpp_2020_Chile.csv",
    "/content/sample_data/viirs-snpp_2021_Chile.csv",
    "/content/sample_data/viirs-snpp_2022_Chile.csv",
    "/content/sample_data/viirs-snpp_2023_Chile.csv",
    "/content/sample_data/viirs-snpp_2024_Chile.csv"
]

dfs = [pd.read_csv(a) for a in archivos]
df_fire_5años = pd.concat(dfs, ignore_index=True)

df_fire_5años.to_csv("Incendios_Chile.csv", index=False)
